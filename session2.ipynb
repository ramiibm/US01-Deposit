# %%
import pandas as pd

# %%
pd.read_excel('Data-sheet-STUDENTS.xlsx')
# Out:
#    Unnamed: 0                         Indicator #                Unnamed: 2  \
# 0   Country #                       Source link:                        NaN
# 1         NaN      Country (according to CN Gov):  Date of research inquiry
# 2           1                         Afghanistan                       NaN
# 3           2                             Albania                       NaN
# 4           3                             Armenia                       NaN
# 5           4                          Azerbaijan                       NaN
# 6           5                             Bahrain                       NaN
# 7           6                          Bangladesh                       NaN
# 8           7                             Belarus                       NaN
# 9           8                              Bhutan                       NaN
# 10          9              Bosnia and Herzegovina                       NaN
# ...

# %%
myfile = pd.read_excel('Data-sheet-STUDENTS.xlsx', header=2,index_col=0)

# %%
for i in myfile.index:
    print(myfile['Country (according to CN Gov):'][i])
# Out:
# Afghanistan
# Albania
# Armenia
# Azerbaijan
# Bahrain
# Bangladesh
# Belarus
# Bhutan
# Bosnia and Herzegovina
# Brunei
# Bulgaria
# Cambodia
# China
# Croatia
# Czech Republic
# East Timor
# Egypt
# Estonia
# France (Not BRI)
# Georgia
# Germany (not BRI)
# Hungary
# India
# Indonesia
# Iran
# Iraq
# Israel
# Jordan
# Kazakhstan
# Kuwait
# Kyrgyzstan
# Laos
# Latvia
# Lebanon
# Lithuania
# Macedonia
# Malaysia
# Maldives
# Moldova
# Mongolia
# Montenegro
# Myanmar
# Nepal
# Oman
# Pakistan
# Philippines
# Poland
# Qatar
# Romania
# Russia
# Saudi Arabia
# Serbia
# Singapore
# Slovakia
# Slovenia
# Sri Lanka
# Syria
# Tajikistan
# Thailiand
# The United Arab Emirates
# Turkey
# Turkmenistan
# United Kingdom (Not BRI)
# United States of America (Not BRI)
# Ukraine
# Uzbekistan
# Vietnam
# Yemen

# %%
for i in myfile.index:
    print('https://restcountries.eu/rest/v2/name/' + myfile['Country (according to CN Gov):'][i])
# Out:
# https://restcountries.eu/rest/v2/name/Afghanistan
# https://restcountries.eu/rest/v2/name/Albania
# https://restcountries.eu/rest/v2/name/Armenia
# https://restcountries.eu/rest/v2/name/Azerbaijan
# https://restcountries.eu/rest/v2/name/Bahrain
# https://restcountries.eu/rest/v2/name/Bangladesh
# https://restcountries.eu/rest/v2/name/Belarus
# https://restcountries.eu/rest/v2/name/Bhutan
# https://restcountries.eu/rest/v2/name/Bosnia and Herzegovina
# https://restcountries.eu/rest/v2/name/Brunei
# https://restcountries.eu/rest/v2/name/Bulgaria
# https://restcountries.eu/rest/v2/name/Cambodia
# https://restcountries.eu/rest/v2/name/China
# https://restcountries.eu/rest/v2/name/Croatia
# https://restcountries.eu/rest/v2/name/Czech Republic
# https://restcountries.eu/rest/v2/name/East Timor
# https://restcountries.eu/rest/v2/name/Egypt
# https://restcountries.eu/rest/v2/name/Estonia
# https://restcountries.eu/rest/v2/name/France (Not BRI)
# https://restcountries.eu/rest/v2/name/Georgia
# ...

# %%
import requests

# %%
r = requests.get('https://restcountries.eu/rest/v2/name/Afghanistan')

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# [{'name': 'Afghanistan',
#   'topLevelDomain': ['.af'],
#   'alpha2Code': 'AF',
#   'alpha3Code': 'AFG',
#   'callingCodes': ['93'],
#   'capital': 'Kabul',
#   'altSpellings': ['AF', 'Afġānistān'],
#   'region': 'Asia',
#   'subregion': 'Southern Asia',
#   'population': 27657145,
#   'latlng': [33.0, 65.0],
#   'demonym': 'Afghan',
#   'area': 652230.0,
#   'gini': 27.8,
#   'timezones': ['UTC+04:30'],
#   'borders': ['IRN', 'PAK', 'TKM', 'UZB', 'TJK', 'CHN'],
#   'nativeName': 'افغانستان',
#   'numericCode': '004',
#   'currencies': [{'code': 'AFN', 'name': 'Afghan afghani', 'symbol': '؋'}],
#   'languages': [{'iso639_1': 'ps',
#     'iso639_2': 'pus',
#     'name': 'Pashto',
#     'nativeName': 'پښتو'},
#    {'iso639_1': 'uz',
#     'iso639_2': 'uzb',
#     'name': 'Uzbek',
#     'nativeName': 'Oʻzbek'},
#    {'iso639_1': 'tk',
#     'iso639_2': 'tuk',
#     'name': 'Turkmen',
#     'nativeName': 'Türkmen'}],
#   'translations': {'de': 'Afghanistan',
#    'es': 'Afganistán',
# ...

# %%
r.json()[0]
# Out:
# {'name': 'Afghanistan',
#  'topLevelDomain': ['.af'],
#  'alpha2Code': 'AF',
#  'alpha3Code': 'AFG',
#  'callingCodes': ['93'],
#  'capital': 'Kabul',
#  'altSpellings': ['AF', 'Afġānistān'],
#  'region': 'Asia',
#  'subregion': 'Southern Asia',
#  'population': 27657145,
#  'latlng': [33.0, 65.0],
#  'demonym': 'Afghan',
#  'area': 652230.0,
#  'gini': 27.8,
#  'timezones': ['UTC+04:30'],
#  'borders': ['IRN', 'PAK', 'TKM', 'UZB', 'TJK', 'CHN'],
#  'nativeName': 'افغانستان',
#  'numericCode': '004',
#  'currencies': [{'code': 'AFN', 'name': 'Afghan afghani', 'symbol': '؋'}],
#  'languages': [{'iso639_1': 'ps',
#    'iso639_2': 'pus',
#    'name': 'Pashto',
#    'nativeName': 'پښتو'},
#   {'iso639_1': 'uz',
#    'iso639_2': 'uzb',
#    'name': 'Uzbek',
#    'nativeName': 'Oʻzbek'},
#   {'iso639_1': 'tk',
#    'iso639_2': 'tuk',
#    'name': 'Turkmen',
#    'nativeName': 'Türkmen'}],
#  'translations': {'de': 'Afghanistan',
#   'es': 'Afganistán',
#   'fr': 'Afghanistan',
# ...

# %%
r.json()[0]['alpha3Code']
# Out:
# 'AFG'

# %%
iso_codes = {}

# %%
for i in myfile.index:
    name = myfile['Country (according to CN Gov):'][i]
    
    if name in iso_codes:
        continue
    
    clean_name = name.split(' (')[0].strip()
    
    if clean_name == 'Thailiand':
        clean_name = 'Thailand'
    elif clean_name == 'The United Arab Emirates':
        clean_name = 'United Arab Emirates'
    
    url = 'https://restcountries.eu/rest/v2/name/' + clean_name
    r = requests.get(url)
    if r.status_code == 200:
        data = r.json()
        iso_codes[name] = data[0]['alpha3Code']
    else:
        print('[ERROR] we cannot get the data, reason is ', r.status_code, r.text)
        print(clean_name)

# %%
iso_codes
# Out:
# {'Afghanistan': 'AFG',
#  'Albania': 'ALB',
#  'Armenia': 'ARM',
#  'Azerbaijan': 'AZE',
#  'Bahrain': 'BHR',
#  'Bangladesh': 'BGD',
#  'Belarus': 'BLR',
#  'Bhutan': 'BTN',
#  'Bosnia and Herzegovina': 'BIH',
#  'Brunei': 'BRN',
#  'Bulgaria': 'BGR',
#  'Cambodia': 'KHM',
#  'China': 'CHN',
#  'Croatia': 'HRV',
#  'Czech Republic': 'CZE',
#  'East Timor': 'TLS',
#  'Egypt': 'EGY',
#  'Estonia': 'EST',
#  'Georgia': 'GEO',
#  'Hungary': 'HUN',
#  'India': 'IOT',
#  'Indonesia': 'IDN',
#  'Iran': 'IRN',
#  'Iraq': 'IRQ',
#  'Israel': 'ISR',
#  'Jordan': 'JOR',
#  'Kazakhstan': 'KAZ',
#  'Kuwait': 'KWT',
#  'Kyrgyzstan': 'KGZ',
#  'Laos': 'LAO',
#  'Latvia': 'LVA',
#  'Lebanon': 'LBN',
#  'Lithuania': 'LTU',
#  'Macedonia': 'MKD',
#  'Malaysia': 'MYS',
#  'Maldives': 'MDV',
#  'Moldova': 'MDA',
#  'Mongolia': 'MNG',
#  'Montenegro': 'MNE',
#  'Myanmar': 'MMR',
#  'Nepal': 'NPL',
#  'Oman': 'OMN',
#  'Pakistan': 'PAK',
#  'Philippines': 'PHL',
#  'Poland': 'POL',
#  'Qatar': 'QAT',
# ...

# %%
name = 'France (Not BRI)'
clean_name = name.split('(')[0].strip()
print(clean_name)
# Out:
# France

# %%
myfile['isocode'] = myfile['Country (according to CN Gov):'].apply(lambda x: iso_codes[x])

# %%
myfile['isocode']
# Out:
# 1     AFG
# 2     ALB
# 3     ARM
# 4     AZE
# 5     BHR
# 6     BGD
# 7     BLR
# 8     BTN
# 9     BIH
# 10    BRN
# 11    BGR
# 12    KHM
# 13    CHN
# 14    HRV
# 15    CZE
# 16    TLS
# 17    EGY
# 18    EST
# 19    FRA
# 20    GEO
# 21    DEU
# 22    HUN
# 23    IOT
# 24    IDN
# 25    IRN
# 26    IRQ
# 27    ISR
# 28    JOR
# 29    KAZ
# 30    KWT
#      ...
# 39    MDA
# 40    MNG
# 41    MNE
# 42    MMR
# 43    NPL
# 44    OMN
# 45    PAK
# 46    PHL
# 47    POL
# 48    QAT
# 49    ROU
# 50    RUS
# 51    SAU
# 52    SRB
# 53    SGP
# 54    SVK
# 55    SVN
# 56    LKA
# 57    SYR
# 58    TJK
# 59    THA
# 60    ARE
# 61    TUR
# 62    TKM
# 63    GBR
# 64    USA
# 65    UKR
# 66    UZB
# 67    VNM
# 68    YEM
# Name: isocode, Length: 68, dtype: object

# %%
myfile[['isocode', 'Country (according to CN Gov):']]
# Out:
#    isocode      Country (according to CN Gov):
# 1      AFG                         Afghanistan
# 2      ALB                             Albania
# 3      ARM                             Armenia
# 4      AZE                          Azerbaijan
# 5      BHR                             Bahrain
# 6      BGD                          Bangladesh
# 7      BLR                             Belarus
# 8      BTN                              Bhutan
# 9      BIH              Bosnia and Herzegovina
# 10     BRN                              Brunei
# 11     BGR                            Bulgaria
# 12     KHM                            Cambodia
# 13     CHN                               China
# 14     HRV                             Croatia
# 15     CZE                      Czech Republic
# 16     TLS                          East Timor
# 17     EGY                               Egypt
# 18     EST                             Estonia
# 19     FRA                    France (Not BRI)
# ...

# %%
myfile[['isocode', 'Country (according to CN Gov):']].loc[10]
# Out:
# isocode                              BRN
# Country (according to CN Gov):    Brunei
# Name: 10, dtype: object

# %%
url = 'http://api.worldbank.org/v2/country/CHN/indicator/GC.TAX.IMPT.ZS?format=json'
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
if r.status_code == 200:
        data = r.json()
        print(data[1][2]['value'])
# Out:
# 3.89434134127694

# %%
iso_codes
# Out:
# {'Afghanistan': 'AFG',
#  'Albania': 'ALB',
#  'Armenia': 'ARM',
#  'Azerbaijan': 'AZE',
#  'Bahrain': 'BHR',
#  'Bangladesh': 'BGD',
#  'Belarus': 'BLR',
#  'Bhutan': 'BTN',
#  'Bosnia and Herzegovina': 'BIH',
#  'Brunei': 'BRN',
#  'Bulgaria': 'BGR',
#  'Cambodia': 'KHM',
#  'China': 'CHN',
#  'Croatia': 'HRV',
#  'Czech Republic': 'CZE',
#  'East Timor': 'TLS',
#  'Egypt': 'EGY',
#  'Estonia': 'EST',
#  'France (Not BRI)': 'FRA',
#  'Georgia': 'GEO',
#  'Germany (not BRI)': 'DEU',
#  'Hungary': 'HUN',
#  'India': 'IOT',
#  'Indonesia': 'IDN',
#  'Iran': 'IRN',
#  'Iraq': 'IRQ',
#  'Israel': 'ISR',
#  'Jordan': 'JOR',
#  'Kazakhstan': 'KAZ',
#  'Kuwait': 'KWT',
#  'Kyrgyzstan': 'KGZ',
#  'Laos': 'LAO',
#  'Latvia': 'LVA',
#  'Lebanon': 'LBN',
#  'Lithuania': 'LTU',
#  'Macedonia': 'MKD',
#  'Malaysia': 'MYS',
#  'Maldives': 'MDV',
#  'Moldova': 'MDA',
#  'Mongolia': 'MNG',
#  'Montenegro': 'MNE',
#  'Myanmar': 'MMR',
#  'Nepal': 'NPL',
#  'Oman': 'OMN',
#  'Pakistan': 'PAK',
# ...

# %%
myfile.to_pickle('isocode')

# %%
indicator_value = {}

for i in myfile.index:
    isocode = myfile['isocode'][i]
    url = 'http://api.worldbank.org/v2/country/' + isocode + '/indicator/GC.TAX.IMPT.ZS?format=json'
    r = requests.get(url)
    if r.status_code == 200:
        data = r.json()
        indicator_value[isocode] = data[1][2]['value']
        print(indicator_value)
    else:
        print('[ERROR] we cannot get the data, reason is ', r.status_code, r.text)
        print(isocode)
    break
# Out:
# {'AFG': 26.3722027480519}
